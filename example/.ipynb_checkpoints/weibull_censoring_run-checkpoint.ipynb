# %%
import sys
import numpy as np
from src import *
from src.simulations import *
from src.vamp import *
from src.utils import *
import warnings
warnings.filterwarnings('ignore')

# %%
# Bernoulli - Gaussian prior on beta (with censoring LMMSE)
la, h2, mu, distr = 0.1, 0.5, 0, "Gaussian"
n, m = 1600, 1000
X, beta_true, y, alpha, problem_instance, tot_nans, valid_stds, mask = synthetic_data(n=n, m=m, p=0.4, la=la, h2=h2, mu=mu, \
                                                                                      omega=1, seed=42, distr=distr, print_results=True, sigma=None, model='Weibull',
                                                                                          censoring=0.4, censor_min=0.0, censor_max=1.0)      
X_c, y_c, X, y = X[mask==0], y[mask==0], X[mask==1], y[mask==1]                                                                      
print(f"Var(logY) = {np.var(np.log(y))}")
print(f"Var(z) = {np.var(X @ beta_true)}")
print(f"alpha = {alpha}")
print(f"mu = {mu}")
data = {'X':X, 'y':y, 'X_c': X_c, 'y_c': y_c, 'beta_true':beta_true}
Hyp = Hyperparams('Weibull', mu, alpha)
problem = Problem(n=n, m=m, la=la, sigmas=[h2/(la*m)], omegas=[1.0], model='Weibull', hyperparams=Hyp)
pref={'update_mu': False, 'update_alpha': False, 'start_at_mu': mu, 'start_at_alpha': alpha, \
      'mode': 'censoring', 'dampen_coeff':1.0, 'save': False, 'print_results': True, 'tau1':1e-4}
infere_and_visualize(data, problem, pref, seed=15, maxiter=10, h2_title=h2, distr=distr)
# Out:
# Variance of slab part of beta: 0.004681702067624251
# Simulating data with sigma: 0.005
# Working under the following model: Weibull
# Var(logY) = 0.0010540030717116622
# Var(z) = 0.00046516717235166316
# alpha = 59.49936430952176
# mu = 0
# gam1 = 0.0001
# tau1 = 0.0001
# **** iteration =  0  ****
#
# ->DENOISING
# x1_hat[2] =  [0.]
# alpha1_new =  4.999996375002207e-08
# alpha1 =  4.999996375002207e-08
# true gam2 =  2026.3227149900647
# gam2 =  2000.0013500001687
# corr(z1_hat, X*beta_true) =  0.5776549829382677
# l2 error for z1_hat =  0.9272209294636494
# v1 =  1.9037887142841796e-06
# true tau2 =  2508.9329960250984
# tau2 = 52.526737274376735
# ->LMMSE
# alpha2 = 0.9758217020649261
# beta2 = 0.025009693935892575
# corr(x2_hat, beta_true) =  [[0.22750247]]
# l2 error for x2_hat =  0.9851581294291593
# alpha2 =  0.9758217020649261
# true gam1 =  202.96333105238696
# gam1 =  49.55477871472531
# corr(z2_hat, beta_true) =  [[0.40110051]]
# l2 error for z2_hat =  0.9699044088128702
# ...

# %%
# Bernoulli - Gaussian prior on beta (with standard LMMSE on censored data)
la, h2, mu, distr = 0.1, 0.5, 0, "Gaussian"
n, m = 1600, 1000
X, beta_true, y, alpha, problem_instance, tot_nans, valid_stds, mask = synthetic_data(n=n, m=m, p=0.4, la=la, h2=h2, mu=mu, \
                                                                                      omega=1, seed=42, distr=distr, print_results=True, sigma=None, model='Weibull',
                                                                                          censoring=0.4, censor_min=0.0, censor_max=1.0)      
X_c, y_c, X, y = X[mask==0], y[mask==0], X[mask==1], y[mask==1]                                                                      
print(f"Var(logY) = {np.var(np.log(y))}")
print(f"Var(z) = {np.var(X @ beta_true)}")
print(f"alpha = {alpha}")
print(f"mu = {mu}")
data = {'X':X, 'y':y, 'X_c': X_c, 'y_c': y_c, 'beta_true':beta_true}
Hyp = Hyperparams('Weibull', mu, alpha)
problem = Problem(n=n, m=m, la=la, sigmas=[h2/(la*m)], omegas=[1.0], model='Weibull', hyperparams=Hyp)
pref={'update_mu': False, 'update_alpha': False, 'start_at_mu': mu, 'start_at_alpha': alpha, \
      'mode': 'svd', 'dampen_coeff':1.0, 'save': False, 'print_results': True, 'tau1':1e-4}
infere_and_visualize(data, problem, pref, seed=15, maxiter=10, h2_title=h2, distr=distr)
# Out:
# Variance of slab part of beta: 0.004681702067624251
# Simulating data with sigma: 0.005
# Working under the following model: Weibull
# Var(logY) = 0.0010540030717116622
# Var(z) = 0.00046516717235166316
# alpha = 59.49936430952176
# mu = 0
# gam1 = 0.0001
# tau1 = 0.0001
# performing SVD decoposition..
# **** iteration =  0  ****
#
# ->DENOISING
# x1_hat[2] =  [0.]
# alpha1_new =  4.999996375002207e-08
# alpha1 =  4.999996375002207e-08
# true gam2 =  2026.3227149900647
# gam2 =  2000.0013500001687
# corr(z1_hat, X*beta_true) =  0.5776549829382677
# l2 error for z1_hat =  0.9272209294636494
# v1 =  1.9037887142841796e-06
# true tau2 =  2508.9329960250984
# tau2 = 52.526737274376735
# ->LMMSE
# corr(x2_hat, beta_true) =  [[0.4701194]]
# l2 error for x2_hat =  0.987036262340414
# alpha2 =  0.9359868016531486
# true gam1 =  2598.56729857195
# gam1 =  136.78235941512182
# corr(z2_hat, beta_true) =  [[0.65803908]]
# l2 error for z2_hat =  0.971435771225846
# true tau1 =  2100.25648184424
# ...

# %%
# Bernoulli - Gaussian prior on beta (with standard LMMSE, no censoring)
la, h2, mu, distr = 0.1, 0.5, 0, "Gaussian"
n, m = 1600, 1000
X, beta_true, y, alpha, problem_instance, tot_nans, valid_stds, mask = synthetic_data(n=n, m=m, p=0.4, la=la, h2=h2, mu=mu, \
                                                                                      omega=1, seed=42, distr=distr, print_results=True, sigma=None, model='Weibull',
                                                                                          censoring=0.0, censor_min=0.0, censor_max=1.0)      
X_c, y_c, X, y = X[mask==0], y[mask==0], X[mask==1], y[mask==1]                                                                      
print(f"Var(logY) = {np.var(np.log(y))}")
print(f"Var(z) = {np.var(X @ beta_true)}")
print(f"alpha = {alpha}")
print(f"mu = {mu}")
data = {'X':X, 'y':y, 'X_c': X_c, 'y_c': y_c, 'beta_true':beta_true}
Hyp = Hyperparams('Weibull', mu, alpha)
problem = Problem(n=n, m=m, la=la, sigmas=[h2/(la*m)], omegas=[1.0], model='Weibull', hyperparams=Hyp)
pref={'update_mu': False, 'update_alpha': False, 'start_at_mu': mu, 'start_at_alpha': alpha, \
      'mode': 'svd', 'dampen_coeff':1.0, 'save': False, 'print_results': True, 'tau1':1e-4}
infere_and_visualize(data, problem, pref, seed=15, maxiter=10, h2_title=h2, distr=distr)
# Out:
# Variance of slab part of beta: 0.004681702067624251
# Simulating data with sigma: 0.005
# Working under the following model: Weibull
# Var(logY) = 0.0010197939266469753
# Var(z) = 0.0004646477553694699
# alpha = 59.49936430952176
# mu = 0
# gam1 = 0.0001
# tau1 = 0.0001
# performing SVD decoposition..
# **** iteration =  0  ****
#
# ->DENOISING
# x1_hat[2] =  [0.]
# alpha1_new =  4.999996375002207e-08
# alpha1 =  4.999996375002207e-08
# true gam2 =  2026.3227149900647
# gam2 =  2000.0013500001687
# corr(z1_hat, X*beta_true) =  0.5661611049490743
# l2 error for z1_hat =  0.938779482621309
# v1 =  1.401992297266958e-06
# true tau2 =  2453.0473008654285
# tau2 = 71.3269680551811
# ->LMMSE
# corr(x2_hat, beta_true) =  [[0.5815236]]
# l2 error for x2_hat =  0.9723821861087689
# alpha2 =  0.9476058917367416
# true gam1 =  2580.1121681334607
# gam1 =  110.58213986673216
# corr(z2_hat, beta_true) =  [[0.69049775]]
# l2 error for z2_hat =  0.9553907044621851
# true tau1 =  2273.398032458474
# ...

# %%
# Bernoulli - Gaussian prior on beta (with censoring LMMSE via Hutchinson of order of magnitude smaller, i.e. 100) 
la, h2, mu, distr = 0.1, 0.5, 0, "Gaussian"
n, m = 1600, 1000
X, beta_true, y, alpha, problem_instance, tot_nans, valid_stds, mask = synthetic_data(n=n, m=m, p=0.4, la=la, h2=h2, mu=mu, \
                                                                                      omega=1, seed=42, distr=distr, print_results=True, sigma=None, model='Weibull',
                                                                                          censoring=0.4, censor_min=0.0, censor_max=1.0)      
X_c, y_c, X, y = X[mask==0], y[mask==0], X[mask==1], y[mask==1]                                                                      
print(f"Var(logY) = {np.var(np.log(y))}")
print(f"Var(z) = {np.var(X @ beta_true)}")
print(f"alpha = {alpha}")
print(f"mu = {mu}")
data = {'X':X, 'y':y, 'X_c': X_c, 'y_c': y_c, 'beta_true':beta_true}
Hyp = Hyperparams('Weibull', mu, alpha)
problem = Problem(n=n, m=m, la=la, sigmas=[h2/(la*m)], omegas=[1.0], model='Weibull', hyperparams=Hyp)
pref={'update_mu': False, 'update_alpha': False, 'start_at_mu': mu, 'start_at_alpha': alpha, \
      'mode': 'censoring', 'dampen_coeff':1.0, 'save': False, 'print_results': True, 'tau1':1e-4, \
      'num_hutchinson_samples': 100}
infere_and_visualize(data, problem, pref, seed=15, maxiter=10, h2_title=h2, distr=distr)
# Out:
# Variance of slab part of beta: 0.004681702067624251
# Simulating data with sigma: 0.005
# Working under the following model: Weibull
# Var(logY) = 0.0010540030717116622
# Var(z) = 0.00046516717235166316
# alpha = 59.49936430952176
# mu = 0
# gam1 = 0.0001
# tau1 = 0.0001
# **** iteration =  0  ****
#
# ->DENOISING
# x1_hat[2] =  [0.]
# alpha1_new =  4.999996375002207e-08
# alpha1 =  4.999996375002207e-08
# true gam2 =  2026.3227149900647
# gam2 =  2000.0013500001687
# corr(z1_hat, X*beta_true) =  0.5776549829382677
# l2 error for z1_hat =  0.9272209294636494
# v1 =  1.9037887142841796e-06
# true tau2 =  2508.9329960250984
# tau2 = 52.526737274376735
# ->LMMSE
# alpha2 = 0.9758726821518882
# beta2 = 0.6301204229882892
# corr(x2_hat, beta_true) =  [[0.22750247]]
# l2 error for x2_hat =  0.9851581294291593
# alpha2 =  0.9758726821518882
# true gam1 =  202.13078548742757
# gam1 =  49.44770885654972
# corr(z2_hat, beta_true) =  [[0.40110051]]
# l2 error for z2_hat =  0.9699044088128702
# ...
